# %%
import visualizations as vis
import numpy as np
from random import randint

# %%
randint(0,100)
# Out:
# 63

# %%
delta = 500

def relate(stuffies):
    if (randint(0,1000) > stuffies[0]):
        stuffies[1] += delta
    else:
        stuffies[1] -= delta
    if (stuffies[1] > 1000):
        stuffies[1] = 1000
    if (stuffies[1] < 0):
        stuffies[1] = 0
    return stuffies[1]

    
stampi = 500
marvel = 500
sockmonster = 500
for i in xrange(10000):
    stampi = relate([marvel,stampi])
#     marvel = relate([stampi,marvel])
    sockmonster = relate([stampi,sockmonster])
#     stampi = relate([sockmonster, stampi])
    marvel = relate([sockmonster, marvel])
#     sockmonster = relate([marvel, sockmonster])
    print [stampi, marvel, sockmonster]
# Out:
# [1000, 1000, 0]
# [500, 500, 500]
# [1000, 1000, 0]
# [500, 1000, 0]
# [0, 1000, 500]
# [0, 500, 1000]
# [500, 0, 1000]
# [1000, 0, 500]
# [1000, 500, 0]
# [1000, 1000, 0]
# [500, 1000, 0]
# [0, 1000, 500]
# [0, 500, 1000]
# [0, 0, 1000]
# [500, 0, 1000]
# [1000, 0, 500]
# [1000, 500, 0]
# [500, 1000, 0]
# [0, 500, 500]
# [0, 0, 1000]
# [500, 0, 500]
# [1000, 500, 0]
# [500, 1000, 0]
# [0, 500, 500]
# [0, 0, 1000]
# [500, 0, 500]
# [1000, 500, 0]
# [1000, 1000, 0]
# [500, 1000, 0]
# [0, 500, 500]
# [500, 0, 1000]
# [1000, 0, 500]
# [1000, 500, 0]
# [1000, 1000, 0]
# [500, 1000, 0]
# [0, 1000, 500]
# [0, 500, 1000]
# [0, 0, 1000]
# [500, 0, 500]
# [1000, 500, 0]
# [500, 1000, 0]
# [0, 1000, 500]
# [0, 500, 1000]
# [0, 0, 1000]
# [500, 0, 500]
# [1000, 500, 0]
# [500, 0, 500]
# [1000, 500, 0]
# [1000, 1000, 0]
# [500, 500, 500]
# [0, 0, 1000]
# [500, 500, 500]
# [1000, 1000, 0]
# [500, 1000, 500]
# [0, 500, 1000]
# [0, 0, 1000]
# [500, 500, 500]
# [1000, 1000, 0]
# [500, 500, 500]
# ...
